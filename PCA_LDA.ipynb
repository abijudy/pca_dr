# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %%
# Load dataset
dataset = pd.read_csv('wustl.csv')
dataset.head(5)
# Out:
#      Dir        Flgs     SrcAddr     DstAddr  Sport  Dport  SrcBytes  \
# 0     ->   e          10.0.1.172  10.0.1.150  58059   1111     496.0
# 1     ->   e          10.0.1.172  10.0.1.150  58062   1111     496.0
# 2     ->   e          10.0.1.172  10.0.1.150  58065   1111     496.0
# 3     ->   e          10.0.1.172  10.0.1.150  58067   1111     496.0
# 4     ->   e          10.0.1.172  10.0.1.150  58069   1111     496.0
#
#    DstBytes   SrcLoad  DstLoad  ...  Packet_num  Temp  SpO2  Pulse_Rate  SYS  \
# 0     186.0  276914.0  92305.0  ...           1  28.9     0           0    0
# 1     186.0  230984.0  76995.0  ...           2  28.9     0           0    0
# 2     186.0  218470.0  72823.0  ...           3  28.9    89         104    0
# 3     186.0  203376.0  67792.0  ...           4  28.9    89         104    0
# 4     186.0  235723.0  78574.0  ...           5  28.9    89         101    0
#
#    DIA  Heart_rate  Resp_Rate   ST  Label
# 0    0           0          0  0.0      0
# ...

# %%
X = dataset.drop('Dir', axis=1,inplace=True)
x1 = dataset.drop('SrcAddr', axis=1,inplace=True)
x1 = dataset.drop('DstAddr', axis=1,inplace=True)
x1 = dataset.drop('Sport', axis=1,inplace=True)
x1 = dataset.drop('Dport', axis=1,inplace=True)
x1 = dataset.drop('SrcMac', axis=1,inplace=True)
x1 = dataset.drop('DstMac', axis=1,inplace=True)
df= dataset.drop('Flgs', axis=1)
#df=dataset.drop('Sport',axis=1)
print (df)
# Out:
#        SrcBytes  DstBytes   SrcLoad  DstLoad  SrcGap  DstGap   SIntPkt  \
# 0         496.0     186.0  276914.0  92305.0     0.0     0.0  3.582333
# 1         496.0     186.0  230984.0  76995.0     0.0     0.0  4.294667
# 2         496.0     186.0  218470.0  72823.0     0.0     0.0  4.540667
# 3         496.0     186.0  203376.0  67792.0     0.0     0.0  4.877667
# 4         496.0     186.0  235723.0  78574.0     0.0     0.0  4.208333
# ...         ...       ...       ...      ...     ...     ...       ...
# 16313     496.0     186.0  205128.0  68376.0     0.0     0.0  4.836000
# 16314     496.0     186.0  274058.0  91353.0     0.0     0.0  3.619667
# 16315     496.0     186.0  288568.0  96189.0     0.0     0.0  3.437667
# 16316     496.0     186.0  237795.0  79265.0     0.0     0.0  4.171667
# 16317     496.0     186.0  278730.0  92910.0     0.0     0.0  3.559000
#
#        DIntPkt  SIntPktAct  DIntPktAct  ...  Packet_num  Temp  SpO2  \
# ...

# %%
X = df.drop('Label', axis=1)
y = dataset.Label
X.head()
# Out:
#    SrcBytes  DstBytes   SrcLoad  DstLoad  SrcGap  DstGap   SIntPkt  DIntPkt  \
# 0     496.0     186.0  276914.0  92305.0     0.0     0.0  3.582333   1.9015
# 1     496.0     186.0  230984.0  76995.0     0.0     0.0  4.294667   2.9015
# 2     496.0     186.0  218470.0  72823.0     0.0     0.0  4.540667   3.2945
# 3     496.0     186.0  203376.0  67792.0     0.0     0.0  4.877667   3.3320
# 4     496.0     186.0  235723.0  78574.0     0.0     0.0  4.208333   2.8635
#
#    SIntPktAct  DIntPktAct  ...     Rate  Packet_num  Temp  SpO2  Pulse_Rate  \
# 0         0.0         0.0  ...  558.295           1  28.9     0           0
# 1         0.0         0.0  ...  465.694           2  28.9     0           0
# 2         0.0         0.0  ...  440.464           3  28.9    89         104
# 3         0.0         0.0  ...  410.032           4  28.9    89         104
# 4         0.0         0.0  ...  475.247           5  28.9    89         101
#
#    SYS  DIA  Heart_rate  Resp_Rate   ST
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-367df9d76a23> in <cell line: 4>()
#       2
#       3 scaler = StandardScaler()
# ----> 4 X_scaled = scaler.fit_transform(X)
#       5 X_scaled
#
# NameError: name 'X' is not defined

# %%
import tensorflow as tf

# Define constants
sequence_length = 10  # Set the appropriate sequence length based on your data
input_dim = 32  # Set the input dimension based on your data
output_dim = 1  # Set the output dimension based on your task

# Define your RNN model
model = tf.keras.Sequential([
    tf.keras.layers.SimpleRNN(64, activation='relu', return_sequences=True, input_shape=(sequence_length, input_dim)),
    # Add more RNN layers or other layers as needed
    # Example: tf.keras.layers.SimpleRNN(64, activation='relu', return_sequences=True),
    # Example: tf.keras.layers.Dense(32, activation='relu'),
    # Example: tf.keras.layers.Dense(output_dim)
])

# Compile your model
model.compile(optimizer='adam', loss='mse')  # You can choose an appropriate loss and optimizer

# Train your model with your data
epochs = 10  # Set the number of epochs to an appropriate value
batch_size = 32  # Set the batch size to an appropriate value

model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size)


# Use the trained model for sequence modeling or dimensionality reduction
output = model.predict(input_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f5977f166020> in <cell line: 21>()
#      19
#      20 # Train your model with your data
# ---> 21 model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size)
#      22
#      23 # Use the trained model for sequence modeling or dimensionality reduction
#
# NameError: name 'x_train' is not defined

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_lda, y, test_size=0.2, random_state=30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-23fe755321cb> in <cell line: 3>()
#       1 from sklearn.model_selection import train_test_split
#       2
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(X_lda, y, test_size=0.2, random_state=30)
#
# NameError: name 'X_lda' is not defined

# %%
# Train model
clf = MLPClassifier(hidden_layer_sizes=(50, 50), max_iter=500, alpha=0.0001, solver='adam',
                    verbose=10,  random_state=21, tol=0.000000001)
clf.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 0.51718951
# Iteration 2, loss = 0.32721646
# Iteration 3, loss = 0.31672491
# Iteration 4, loss = 0.31295949
# Iteration 5, loss = 0.30859357
# Iteration 6, loss = 0.30456230
# Iteration 7, loss = 0.30003164
# Iteration 8, loss = 0.29625790
# Iteration 9, loss = 0.29331852
# Iteration 10, loss = 0.29084764
# Iteration 11, loss = 0.28812863
# Iteration 12, loss = 0.28566888
# Iteration 13, loss = 0.28322587
# Iteration 14, loss = 0.28127133
# Iteration 15, loss = 0.27875167
# Iteration 16, loss = 0.27621750
# Iteration 17, loss = 0.27403126
# Iteration 18, loss = 0.27139841
# Iteration 19, loss = 0.26950000
# Iteration 20, loss = 0.26703456
# Iteration 21, loss = 0.26497214
# Iteration 22, loss = 0.26351318
# Iteration 23, loss = 0.26083607
# Iteration 24, loss = 0.25858077
# Iteration 25, loss = 0.25667038
# Iteration 26, loss = 0.25497058
# Iteration 27, loss = 0.25334310
# Iteration 28, loss = 0.25193743
# Iteration 29, loss = 0.25124615
# ...

# %%
# Make predictions
y_pred = clf.predict(X_test)

# Evaluate model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy*100))
# Out:
# Accuracy: 92.92%

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.datasets import load_iris

# Load the Iris dataset
X, y = df, df.Label

# Define a range of values for k
k_range = range(1, 31)

# Calculate the cross-validation scores for each value of k
cv_scores = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, X, y, cv=10, scoring='accuracy')
    cv_scores.append(scores.mean())

# Find the best value of k that results in the highest accuracy
best_k = k_range[cv_scores.index(max(cv_scores))]
print("Best k:", best_k)
# Out:
# Best k: 18

# %%
from sklearn.neighbors import KNeighborsClassifier

# Create a KNN classifier with k=18
knn = KNeighborsClassifier(n_neighbors=18)

# Train the model on the training set
knn.fit(X_train, y_train)

# Predict the labels of the test set
y_pred = knn.predict(X_test)

# Evaluate the accuracy of the model
accuracy = knn.score(X_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9276960784313726

# %%
import numpy as np
from sklearn import svm


# Train an SVM classifier on the training set
clf = svm.SVC(kernel='linear', C=1, random_state=42)
clf.fit(X_train, y_train)

# Evaluate the classifier on the testing set
y_pred = clf.predict(X_test)
acc = accuracy_score(y_test, y_pred)

print('Accuracy:', acc)
# Out:
# Accuracy: 0.9286151960784313
